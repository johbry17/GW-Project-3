# %%
import pandas as pd

# %%
# Create the dataframe Listing
listing_df= pd.read_csv('listings2.csv')
listing_df
# Out:
#           id                          listing_url       scrape_id  \
# 0       3686    https://www.airbnb.com/rooms/3686  20221220053924
# 1     196429  https://www.airbnb.com/rooms/196429  20221220053924
# 2     198685  https://www.airbnb.com/rooms/198685  20221220053924
# 3     201116  https://www.airbnb.com/rooms/201116  20221220053924
# 4     204741  https://www.airbnb.com/rooms/204741  20221220053924
# ...      ...                                  ...             ...
# 6212  155859  https://www.airbnb.com/rooms/155859  20221220053924
# 6213  164069  https://www.airbnb.com/rooms/164069  20221220053924
# 6214  174808  https://www.airbnb.com/rooms/174808  20221220053924
# 6215  175608  https://www.airbnb.com/rooms/175608  20221220053924
# 6216  178395  https://www.airbnb.com/rooms/178395  20221220053924
#
#      last_scraped       source  \
# 0      2022-12-20  city scrape
# 1      2022-12-20  city scrape
# 2      2022-12-20  city scrape
# 3      2022-12-20  city scrape
# ...

# %%
# Gather all the data about host in a dataframe host
host_df=listing_df[['host_id','id','host_url','host_name','host_since','host_location','host_about',	'host_response_time','host_response_rate','host_acceptance_rate','host_is_superhost','host_thumbnail_url','host_picture_url','host_neighbourhood','host_listings_count','host_total_listings_count','host_verifications','host_has_profile_pic','host_identity_verified']].copy()

# %%
# Display host
host_df.head()
# Out:
#    host_id      id                                   host_url host_name  \
# 0     4645    3686     https://www.airbnb.com/users/show/4645      Vita
# 1   956417  196429   https://www.airbnb.com/users/show/956417     Julia
# 2   966613  198685   https://www.airbnb.com/users/show/966613     Robin
# 3   983611  201116   https://www.airbnb.com/users/show/983611      Reed
# 4  1005751  204741  https://www.airbnb.com/users/show/1005751    Denise
#
#    host_since   host_location  \
# 0  2008-11-26  Washington, DC
# 1  2011-08-11  Washington, DC
# 2  2011-08-13  Washington, DC
# 3  2011-08-17  Washington, DC
# 4  2011-08-22  Washington, DC
#
#                                           host_about  host_response_time  \
# 0  I am a literary scholar, teacher, poet, vegan ...                 NaN
# 1  Professional Mom welcomes you to our home wher...                 NaN
# 2  I'm 41 and have daughter in college. Living an...  a few days or more
# ...

# %%
# Display the number of hosts in the dataframe
print(len(host_df))
# Out:
# 6217

# %%
# Delete redundoncy and print the number of hosts
host_df = host_df.drop_duplicates(subset='host_id')
print(len(host_df))
# Out:
# 3294

# %%
# Create Host Csv file
host_df.to_csv('host_final.csv', index=False)

# %%
# Drop the columns related to host from the dtaframe listing
columns_to_drop = [
    'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
    'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
    'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count',
    'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
    'host_identity_verified'
]
listing_df = listing_df.drop(columns=columns_to_drop)

# %%
# neighbourhood_df= pd.read_csv('neighbourhoods_final.csv')

# %%
# listing_df = listing_df.drop(columns='neighbourhood')
# listing_df = listing_df.drop(columns='neighbourhood_group')

# %%
# listing_df = listing_df.rename(columns={'neighbourhood_cleansed': 'neighbourhood'})
# listing_df = listing_df.rename(columns={'neighbourhood_group_cleansed': 'neighbourhood_group'})

# %%
listing_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
# ...

# %%
# import math
# # Fill the neighberhood_group in listing
# for i, listing_row in listing_df.iterrows():
#     for j, neighbourhood_row in neighbourhood_df.iterrows():
#         if (listing_row['neighbourhood'] == neighbourhood_row['neighbourhood']).any():
#             listing_df.at[i, 'neighbourhood_group'] = int(neighbourhood_row['neighbourhood_group'])

# %%
# neighbourhood_group_dtype = listing_df['neighbourhood_group'].dtypes
# print(neighbourhood_group_dtype)

# %%
# listing_df['neighbourhood_group'].head(10)

# %%
# Create a dataframe for min max nights
min_max_night_df=listing_df[['id','minimum_nights','maximum_nights',	
                             'minimum_minimum_nights',	'maximum_minimum_nights',
                             'minimum_maximum_nights','maximum_maximum_nights',
                             'minimum_nights_avg_ntm','maximum_nights_avg_ntm']].copy()

# %%
# display the dataframe min_max_night_df
min_max_night_df
# Out:
#           id  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       3686              31             365                    31.0
# 1     196429              31            1125                    31.0
# 2     198685              31             365                    31.0
# 3     201116              31             730                    31.0
# 4     204741              31             180                    31.0
# ...      ...             ...             ...                     ...
# 6212  155859              31              62                    31.0
# 6213  164069               2            1125                     2.0
# 6214  174808               2              20                     2.0
# 6215  175608              31             365                    31.0
# 6216  178395              31             730                    31.0
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# ...

# %%
# Drop the columns related to min max night from the dtaframe listing
columns_to_drop = [
    'minimum_nights',
    'maximum_nights',
    'minimum_minimum_nights',	
    'maximum_minimum_nights',
    'minimum_maximum_nights',
    'maximum_maximum_nights',
    'minimum_nights_avg_ntm',
    'maximum_nights_avg_ntm'
]
listing_df = listing_df.drop(columns=columns_to_drop)

# %%
# Create a CSV file for min max nights
min_max_night_df=min_max_night_df.to_csv('min_max_night_final.csv', index=False)

# %%
# Create dataframe for the availability of listing
availability_df=listing_df[['id','has_availability','availability_30',
                             'availability_60',	'availability_90',
                             'availability_365','calendar_last_scraped',
                             'instant_bookable']].copy()

# %%
# display availability_df
availability_df
# Out:
#           id has_availability  availability_30  availability_60  \
# 0       3686                t               30               60
# 1     196429                t               23               53
# 2     198685                t               11               11
# 3     201116                t               26               56
# 4     204741                t                0                0
# ...      ...              ...              ...              ...
# 6212  155859                t               30               60
# 6213  164069                t                0               17
# 6214  174808                t               30               60
# 6215  175608                t                4               34
# 6216  178395                t               30               60
#
#       availability_90  availability_365 calendar_last_scraped instant_bookable
# 0                  90               365            2022-12-20                f
# ...

# %%
# Drop the columns related to min max night from the dtaframe listing
columns_to_drop = [
    'has_availability','availability_30',
                             'availability_60',	'availability_90',
                             'availability_365','calendar_last_scraped',
                             'instant_bookable'
]
listing_df = listing_df.drop(columns=columns_to_drop)

# %%
# Create CSV file for availability
availability_df=availability_df.to_csv('availability_final.csv', index=False)

# %%
# Create dataframe for listing_reviews
listing_reviews_df=listing_df[['id','number_of_reviews','number_of_reviews_ltm',
                             'number_of_reviews_l30d','first_review',
                             'last_review',
                             'review_scores_rating','review_scores_accuracy',	
                             'review_scores_cleanliness', 'review_scores_checkin',
                             'review_scores_communication','review_scores_location','reviews_per_month','review_scores_value'
]].copy()

# %%
# display listing_reviews_df
listing_reviews_df
# Out:
#           id  number_of_reviews  number_of_reviews_ltm  \
# 0       3686                 81                      4
# 1     196429                  7                      1
# 2     198685                154                     14
# 3     201116                220                     25
# 4     204741                116                      2
# ...      ...                ...                    ...
# 6212  155859                130                      0
# 6213  164069                199                      3
# 6214  174808                 57                     19
# 6215  175608                186                      0
# 6216  178395                  0                      0
#
#       number_of_reviews_l30d first_review last_review  review_scores_rating  \
# 0                          0   2010-11-01  2022-07-06                  4.63
# 1                          0   2013-04-23  2022-04-01                  4.20
# ...

# %%
# Drop the columns related to min max night from the dtaframe listing
columns_to_drop = [
    'number_of_reviews','number_of_reviews_ltm',
                             'number_of_reviews_l30d','first_review',
                             'last_review',
                             'review_scores_rating','review_scores_accuracy',	
                             'review_scores_cleanliness', 'review_scores_checkin',
                             'review_scores_communication','review_scores_location','reviews_per_month','review_scores_value'
]
listing_df = listing_df.drop(columns=columns_to_drop)

# %%
# Create CSV file for listing_reviews_df
listing_reviews_df=listing_reviews_df.to_csv('listing_reviews_final.csv', index=False)

# %%
# Create dataframe for calculated_host_listings_df
calculated_host_listings_df=listing_df[['id','calculated_host_listings_count',	'calculated_host_listings_count_entire_homes',	
                                        'calculated_host_listings_count_private_rooms',
                                        'calculated_host_listings_count_shared_rooms']].copy()

# %%
# display listing_reviews_df
calculated_host_listings_df
# Out:
#           id  calculated_host_listings_count  \
# 0       3686                               1
# 1     196429                               1
# 2     198685                               1
# 3     201116                               1
# 4     204741                               2
# ...      ...                             ...
# 6212  155859                               2
# 6213  164069                               4
# 6214  174808                               1
# 6215  175608                               3
# 6216  178395                               2
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               1
# 4                                               0
# ...                                           ...
# 6212                                            1
# ...

# %%
# Drop the columns related calculated_host_listings_df from the dtaframe listing
columns_to_drop = [
    'calculated_host_listings_count',	'calculated_host_listings_count_entire_homes',	
                                        'calculated_host_listings_count_private_rooms',
                                        'calculated_host_listings_count_shared_rooms']
listing_df = listing_df.drop(columns=columns_to_drop)

# %%
# Create CSV file for listing_reviews_df
calculated_host_listings_df=calculated_host_listings_df.to_csv('calculated_host_listings_final.csv', index=False)

# %%
listing_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'calendar_updated', 'license'],
#       dtype='object')

# %%
listing_df1=listing_df[['id','name','description','listing_url','neighborhood_overview','picture_url','neighbourhood','neighbourhood_cleansed',
                        'latitude', 'longitude','property_type','room_type','accommodates','bathrooms_text','bedrooms', 'beds','price','license'
]].copy()

# %%
# Convert the 'price' column to string type
listing_df1['price'] = listing_df['price'].astype(str)

# Remove the '$' symbol and commas and convert to float
listing_df1['price'] = listing_df['price'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# C:\Users\romej\AppData\Local\Temp\ipykernel_9268\2024871754.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   listing_df1['price'] = listing_df['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
# Create fils CSV for listing
listing_df1 = listing_df1.to_csv('listings_final.csv', index=False)
